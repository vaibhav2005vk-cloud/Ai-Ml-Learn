# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhav2005vk-cloud/Ai-Ml-Learn/blob/main/Day%2001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hay")
# Out:
# hay
