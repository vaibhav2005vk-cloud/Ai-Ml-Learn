# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhav2005vk-cloud/Ai-Ml-Learn/blob/main/Day%2001%20python%20advance%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# hay

# %% [markdown]
# Topic python fundamental

# %% [markdown]
# First python program

# %%
print("Vaibhav")
# Out:
# Vaibhav

# %% [markdown]
# Variables

# %%
Name = "vaibhav"
age = 21
height = 5.10
is_studwnt= True

# %% [markdown]
# Type Checking

# %%
type(a)
type(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3652/2936311048.py in <cell line: 0>()
# ----> 1 type(a)
#       2 type(c)
#
# NameError: name 'a' is not defined

# %% [markdown]
# Input Output

# %%
name = (input("enter the name"))
print(name)
# Out:
# enter the nameVaibhav
# Vaibhav

# %% [markdown]
# Basic Pratice

# %%
print("vaibhav")
# store the age
age = 21
#print the  type of age
print(type(age))
# Out:
# vaibhav
# <class 'int'>
